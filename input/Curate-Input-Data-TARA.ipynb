# %% [markdown]
# ## Import provided tables with metadata, curate size fractions specific to Tara oceans data and generate Assembly lists

# %%
import pandas as pd
import argparse

# %%
# # import tables which list metagenomic and metatranscriptomic reads
# metag = pd.read_csv("ENA_tables/PRJEB4352_metaG_wenv.txt", sep = '\t')
# metat = pd.read_csv("ENA_tables/PRJEB6609_metaT_wenv.txt", sep = '\t')

# %%
# def main():
#     p = argparse.ArgumentParser()
#     p.add_argument('projectfile')
#     p.add_argument('--column',default='fastq_ftp', required=False)
#     p.add_argument('--delimiter', default=';', required=False)
#     args = p.parse_args() 
#     #read in file and split the ftp column
#     df = pd.read_table(args.projectfile) 
#     df[['c1', 'c2']]=df[args.column].str.split(args.delimiter, expand=True)
#     #test if PE read by looking for fastq2 file
#     pe_ind = df.c2.notnull()    
#     se_ind = df.c2.isnull()
#     basename = args.projectfile.split('.')[0]
#     PE_out = basename + '_PE.txt'
#     SE_out = basename + '_SE.txt'
#     PE_READS = df.loc[pe_ind].drop(['c1', 'c2'], axis=1)
#     SE_READS = df.loc[se_ind].drop(['c1', 'c2'], axis=1)  
#     PE_READS.to_csv(PE_out, sep='\t') 
#     SE_READS.to_csv(SE_out, sep='\t')

# %%
# import tables which list metagenomic and metatranscriptomic reads
metag = pd.read_csv("ENA_tables/PRJEB4352_metaG_wenv_PE.txt", sep = '\t')
metat = pd.read_csv("ENA_tables/PRJEB6609_metaT_wenv_PE.txt", sep = '\t')

# Generate new columns called size frac
metag['size_frac']= metag['Fraction lower [µm]'].map(str) + '-' + metag['Fraction upper [µm]'].map(str)
metat['size_frac']= metat['Fraction lower [µm]'].map(str) + '-' + metat['Fraction upper [µm]'].map(str)

# %%
metag
# Out:
#      Unnamed: 0 study_accession sample_accession secondary_sample_accession  \
# 0             0       PRJEB4352     SAMEA2656965                  ERS488900
# 1             1       PRJEB4352     SAMEA2620205                  ERS489054
# 2             2       PRJEB4352     SAMEA2623506                  ERS493999
# 3             3       PRJEB4352     SAMEA2620172                  ERS489013
# 4             4       PRJEB4352     SAMEA2730950                  ERS494049
# ..          ...             ...              ...                        ...
# 817         818       PRJEB4352     SAMEA2623579                  ERS494105
# 818         819       PRJEB4352     SAMEA2622038                  ERS491757
# 819         820       PRJEB4352     SAMEA2623246                  ERS493592
# 820         821       PRJEB4352     SAMEA2622679                  ERS492686
# 821         822       PRJEB4352     SAMEA2619981                  ERS488780
#
#     experiment_accession run_accession  tax_id    scientific_name  \
# 0             ERX1771177    ERR1700889  408172  marine metagenome
# 1             ERX1771189    ERR1700890  408172  marine metagenome
# 2             ERX1771187    ERR1700891  408172  marine metagenome
# 3             ERX1771191    ERR1700892  408172  marine metagenome
# 4             ERX1771202    ERR1700893  408172  marine metagenome
# ..                   ...           ...     ...                ...
# 817            ERX953567     ERR873965  408172  marine metagenome
# 818            ERX953571     ERR873966  408172  marine metagenome
# 819            ERX953569     ERR873967  408172  marine metagenome
# 820            ERX953570     ERR873968  408172  marine metagenome
# 821            ERX953563     ERR873969  408172  marine metagenome
#
#         instrument_model library_layout  ...   v [cm/s]        OW MLE [1/day]  \
# 0    Illumina HiSeq 2000         PAIRED  ...  15.046586  0.403157         NaN
# 1    Illumina HiSeq 2000         PAIRED  ...   4.306080 -0.412443    0.026178
# 2    Illumina HiSeq 2000         PAIRED  ...   8.317923 -2.922481    0.044572
# 3    Illumina HiSeq 2000         PAIRED  ... -33.418508  0.043242    0.086921
# 4    Illumina HiSeq 2000         PAIRED  ...  91.787857 -4.707638    0.398799
# ..                   ...            ...  ...        ...       ...         ...
# 817  Illumina HiSeq 2000         PAIRED  ...  91.787857 -4.707638    0.398799
# 818  Illumina HiSeq 2000         PAIRED  ...   1.275138 -0.006839    0.028784
# 819  Illumina HiSeq 2000         PAIRED  ...   1.721794 -1.155182    0.047316
# 820  Illumina HiSeq 2000         PAIRED  ...   5.403076  0.007751    0.028977
# 821  Illumina HiSeq 2000         PAIRED  ...   8.555371 -0.087532    0.061870
#
#      RT [days] Latitude (of the continental shelf with...)  \
# 0     2.250000                                         NaN
# 1    19.027778                                         NaN
# 2    25.750000                                         NaN
# 3     0.000000                                         NaN
# 4     1.083333                                         NaN
# ..         ...                                         ...
# 817   1.083333                                         NaN
# 818   0.000000                                         NaN
# 819  41.666667                                         NaN
# 820  15.833333                                         NaN
# 821   0.000000                                   61.900938
#
#     Longitude (of the continental shelf with...) Age [days]  \
# 0                                            NaN      120.0
# 1                                            NaN      120.0
# 2                                            NaN      120.0
# 3                                            NaN      120.0
# 4                                            NaN      120.0
# ..                                           ...        ...
# 817                                          NaN      120.0
# 818                                          NaN      120.0
# 819                                          NaN      120.0
# 820                                          NaN      120.0
# 821                                    24.819492       50.0
#
#     Latitude (of the geographic coordinate ...)  \
# 0                                     16.583327
# 1                                     14.404658
# 2                                     26.338683
# 3                                     17.386625
# 4                                           NaN
# ..                                          ...
# 817                                         NaN
# 818                                  -25.231969
# 819                                   33.472302
# 820                                  -11.599533
# 821                                   24.428166
#
#     Longitude (of the geographic coordinate ...)      size_frac
# 0                                      63.625415  180.0-2000.00
# 1                                      69.689377      5.0-20.00
# 2                                     -87.272865      5.0-20.00
# 3                                      66.210146      3.0->3.00
# 4                                            NaN      5.0-20.00
# ..                                           ...            ...
# 817                                          NaN       0.8-3.00
# 818                                  -112.818256       0.8-5.00
# 819                                  -120.652510       0.8-3.00
# 820                                  -137.896881       0.8-3.00
# 821                                    61.449162       0.8-5.00
#
# [822 rows x 97 columns]

# %% [markdown]
# ### Tidy Size fraction data splitting

# %%
# Original data -- group by size fractions in 4 distinct groups
pd.DataFrame(metag.groupby('size_frac').count()['study_accession'])
# Out:
#                study_accession
# size_frac
# 0.22-3.00                    1
# 0.8-20.00                    7
# 0.8-3.00                    34
# 0.8-5.00                   204
# 0.8->0.80                   79
# 180.0-2000.00              179
# 20.0-180.00                167
# 3.0->3.00                   14
# 3.0->5.00                    1
# 5.0-20.00                  136

# %%
#drop 0.22 sample
metag = metag[metag.size_frac != '0.22-3.00']
metag = metag.replace('0.8->0.80', '0.8-5.00')
metag = metag.replace('0.8-20.00', '0.8-5.00')
metag = metag.replace('0.8-3.00', '0.8-5.00')
metag = metag.replace('3.0->3.00', '0.8-5.00')
metag = metag.replace('3.0->5.00', '0.8-5.00')
metag = metag.replace('180.0-2000.00', '180-2000.00')
metag = metag.replace('20.0-180.00', '20-180.00')
metag = metag.replace('5.0-20.00', '5-20.00')

#Check final groupings
pd.DataFrame(metag.groupby('size_frac').count()['study_accession'])
# Out:
#              study_accession
# size_frac
# 0.8-5.00                 339
# 180-2000.00              179
# 20-180.00                167
# 5-20.00                  136

# %%
#drop 0.22 sample
metat = metat.replace('0.8->0.80', '0.8-5.00')
metat = metat.replace('0.8-20.00', '0.8-5.00')
metat = metat.replace('0.8-3.00', '0.8-5.00')
metat = metat.replace('3.0->3.00', '0.8-5.00')
metat = metat.replace('3.0->5.00', '0.8-5.00')
metat = metat.replace('180.0-2000.00', '180-2000.00')
metat = metat.replace('20.0-180.00', '20-180.00')
metat = metat.replace('5.0-20.00', '5-20.00')


pd.DataFrame(metat.groupby('size_frac').count()['study_accession'])
# Out:
#              study_accession
# size_frac
# 0.8-5.00                 316
# 180-2000.00              183
# 20-180.00                178
# 5-20.00                  164

# %% [markdown]
# ## Check Ocean Region and Depth and clean

# %%
metag['OS'] = metag['OS region'].str.split(' ').str[0].str.strip('[').str.strip(']')
metag['EF'] = metag['Env feature'].str.split(' ').str[0].str.strip('[').str.strip(']')
metag['BG'] = metag['BG province'].str.split(' ').str[0].str.strip('[').str.strip(']')

# %%
metat['OS'] = metat['OS region'].str.split(' ').str[0].str.strip('[').str.strip(']')
metat['EF'] = metat['Env feature'].str.split(' ').str[0].str.strip('[').str.strip(']')
metat['BG'] = metat['BG province'].str.split(' ').str[0].str.strip('[').str.strip(']')

# %%
subset = ['study_accession', 'run_accession', 'Station', 'size_frac', 'Env feature', 
        'Sample material', 'Depth, nominal', 'OS region', 'BG province',
        'Latitude', 'Longitude', 'OS', 'EF', 'BG']

metag_subset = metag[subset]
metat_subset = metat[subset]

# %% [markdown]
# ## Function to split into groups (for assembly)

# %%
def split_assembly_groups(df, OS_list):
    df['ERR_list']= df.groupby(['OS', 'EF', 'size_frac'])['run_accession'].transform(lambda x: ', '.join(x))
    df_combo = df[['OS', 'EF', 'size_frac','ERR_list']].drop_duplicates()
    df = df.drop('ERR_list', axis =1)
    for O in OS_list:
        df_combo = df_combo[df_combo.OS != O]
        tmp = df[df.OS == O]
        tmp['ERR_list']=tmp.groupby(['OS','BG', 'EF', 'size_frac'])['run_accession'].transform(lambda x: ', '.join(x))
        tmp_combo =tmp[['OS', 'BG', 'EF', 'size_frac','ERR_list']].drop_duplicates()
    final_combo = pd.concat([df_combo, tmp_combo])  
    final_combo = final_combo.fillna('all')
    final_combo['Assembly_group'] = final_combo.OS + '-' + final_combo.BG + '-' + final_combo.EF + '-' +final_combo.size_frac
    final_combo['Sub_region'] = final_combo.OS + '-' + final_combo.BG
    final_combo['Depth_sizefrac'] = final_combo.EF + '-' +final_combo.size_frac
    final_combo['ERR_count']= final_combo['ERR_list'].str.split(', ').str.len()
    final_combo = final_combo[['Sub_region', 'Depth_sizefrac', 'ERR_count', 'ERR_list', 'Assembly_group']]
    final_combo = final_combo.set_index('Sub_region')
    return(final_combo)

# %%
OS_list = ['SPO']
metag_out = split_assembly_groups(metag, OS_list)
metat_out = split_assembly_groups(metat, OS_list)

metag_out.to_csv('SampleList_ForAssembly_metaG_python.txt', sep = '\t')
metat_out.to_csv('SampleList_ForAssembly_metaT_python.txt', sep = '\t')
# Out:
# /vortexfs1/home/sarahhu/.conda/envs/r_3.5.1/lib/python3.6/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /vortexfs1/home/sarahhu/.conda/envs/r_3.5.1/lib/python3.6/site-packages/ipykernel_launcher.py:10: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   # Remove the CWD from sys.path while we load stuff.
# /vortexfs1/home/sarahhu/.conda/envs/r_3.5.1/lib/python3.6/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /vortexfs1/home/sarahhu/.conda/envs/r_3.5.1/lib/python3.6/site-packages/ipykernel_launcher.py:10: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   # Remove the CWD from sys.path while we load stuff.

# %%
metag_out.sort_values(['ERR_count'])
# Out:
#              Depth_sizefrac  ERR_count  \
# Sub_region
# SPO-CHIL       MES-0.8-5.00          1
# SPO-PEOD       MES-0.8-5.00          1
# SPO-CHIL      DCM-20-180.00          1
# RS-all          DCM-5-20.00          1
# SO-all        DCM-20-180.00          1
# SPO-CHIL        DCM-5-20.00          2
# NAO-all         MIX-5-20.00          2
# SPO-PEOD    DCM-180-2000.00          2
# NAO-all     MIX-180-2000.00          2
# SPO-PEOD        DCM-5-20.00          2
# SO-all         MES-0.8-5.00          2
# SPO-CHIL    DCM-180-2000.00          2
# SPO-PEOD      SRF-20-180.00          2
# SPO-PEOD        SRF-5-20.00          2
# SO-all          DCM-5-20.00          2
# SPO-PEOD      DCM-20-180.00          2
# SPO-PEOD    SRF-180-2000.00          2
# SO-all      DCM-180-2000.00          2
# SPO-CHIL       DCM-0.8-5.00          2
# RS-all         DCM-0.8-5.00          2
# IO-all         FSW-0.8-5.00          2
# RS-all        DCM-20-180.00          3
# SO-all         DCM-0.8-5.00          3
# RS-all      DCM-180-2000.00          3
# NAO-all       MIX-20-180.00          3
# SPO-CHIL        SRF-5-20.00          3
# SPO-CHIL      SRF-20-180.00          4
# NAO-all       DCM-20-180.00          4
# SPO-PEOD       SRF-0.8-5.00          4
# SO-all          SRF-5-20.00          4
# ...                     ...        ...
# NPO-all       DCM-20-180.00         11
# NAO-all       SRF-20-180.00         11
# NAO-all         SRF-5-20.00         11
# IO-all      DCM-180-2000.00         12
# SPO-SPSG    DCM-180-2000.00         12
# NPO-all     SRF-180-2000.00         12
# SAO-all         SRF-5-20.00         12
# IO-all          SRF-5-20.00         12
# MS-all        SRF-20-180.00         13
# IO-all         DCM-0.8-5.00         13
# NAO-all     SRF-180-2000.00         13
# SAO-all     SRF-180-2000.00         13
# NPO-all         SRF-5-20.00         13
# NPO-all       SRF-20-180.00         13
# SAO-all       SRF-20-180.00         14
# MS-all         SRF-0.8-5.00         14
# NPO-all        DCM-0.8-5.00         15
# MS-all      SRF-180-2000.00         15
# IO-all        SRF-20-180.00         17
# SPO-SPSG        SRF-5-20.00         18
# SPO-SPSG       DCM-0.8-5.00         19
# IO-all         SRF-0.8-5.00         20
# NPO-all        SRF-0.8-5.00         20
# NAO-all        SRF-0.8-5.00         20
# IO-all      SRF-180-2000.00         21
# SAO-all        SRF-0.8-5.00         23
# SPO-SPSG      SRF-20-180.00         25
# SPO-SPSG    SRF-180-2000.00         27
# SPO-SPSG       SRF-0.8-5.00         33
# SAO-all        DCM-0.8-5.00         40
#
#                                                      ERR_list  \
# Sub_region
# SPO-CHIL                                            ERR868377
# SPO-PEOD                                            ERR868362
# SPO-CHIL                                           ERR1726830
# RS-all                                             ERR1726910
# SO-all                                              ERR599288
# SPO-CHIL                               ERR1700901, ERR1726828
# NAO-all                                ERR1726545, ERR1726756
# SPO-PEOD                               ERR1700911, ERR1726962
# NAO-all                                ERR1726532, ERR1726941
# SPO-PEOD                               ERR1726562, ERR1726742
# SO-all                                   ERR599217, ERR599227
# SPO-CHIL                               ERR1726566, ERR1726627
# SPO-PEOD                               ERR1726577, ERR1726709
# SPO-PEOD                               ERR1726594, ERR1726841
# SO-all                                  ERR1740327, ERR599206
# SPO-PEOD                               ERR1726659, ERR1726727
# SPO-PEOD                               ERR1726705, ERR1726795
# SO-all                                  ERR1726812, ERR599310
# SPO-CHIL                                 ERR868358, ERR868505
# RS-all                                   ERR868348, ERR868439
# IO-all                                   ERR868368, ERR868484
# RS-all                     ERR1726568, ERR1726610, ERR1726960
# SO-all                        ERR599239, ERR599325, ERR868361
# RS-all                     ERR1726537, ERR1726578, ERR1726905
# NAO-all                    ERR1726653, ERR1726803, ERR1726947
# SPO-CHIL                   ERR1726632, ERR1726713, ERR1726878
# SPO-CHIL       ERR1726524, ERR1726525, ERR1726850, ERR1726952
# NAO-all        ERR1726529, ERR1726852, ERR1726893, ERR1726911
# SPO-PEOD         ERR1726628, ERR1726851, ERR868357, ERR868462
# SO-all           ERR1726939, ERR1726968, ERR599224, ERR599228
# ...                                                       ...
# NPO-all     ERR1726563, ERR1726641, ERR1726647, ERR1726658...
# NAO-all     ERR1726581, ERR1726625, ERR1726635, ERR1726720...
# NAO-all     ERR1700893, ERR1700902, ERR1726534, ERR1726542...
# IO-all      ERR1726526, ERR1726686, ERR1726696, ERR1726746...
# SPO-SPSG    ERR1726550, ERR1726552, ERR1726604, ERR1726623...
# NPO-all     ERR1726536, ERR1726619, ERR1726738, ERR1726747...
# SAO-all     ERR1700898, ERR1726626, ERR1726881, ERR1726969...
# IO-all      ERR1700890, ERR1700899, ERR1726575, ERR1726677...
# MS-all      ERR1726546, ERR1726613, ERR1726642, ERR1726660...
# IO-all      ERR1726633, ERR1726897, ERR599323, ERR599324, ...
# NAO-all     ERR1726553, ERR1726638, ERR1726654, ERR1726712...
# SAO-all     ERR1726678, ERR1726689, ERR1726819, ERR1726928...
# NPO-all     ERR1700910, ERR1726559, ERR1726640, ERR1726669...
# NPO-all     ERR1726580, ERR1726621, ERR1726661, ERR1726687...
# SAO-all     ERR1726636, ERR1726663, ERR1726731, ERR1726853...
# MS-all      ERR1726597, ERR538173, ERR538186, ERR868356, E...
# NPO-all     ERR1726523, ERR1726570, ERR1726724, ERR1726760...
# MS-all      ERR1726574, ERR1726612, ERR1726662, ERR1726681...
# IO-all      ERR1700914, ERR1726587, ERR1726599, ERR1726611...
# SPO-SPSG    ERR1726522, ERR1726533, ERR1726535, ERR1726571...
# SPO-SPSG    ERR1726527, ERR1726579, ERR1726584, ERR1726609...
# IO-all      ERR1726549, ERR1740328, ERR599210, ERR599266, ...
# NPO-all     ERR1726576, ERR1726730, ERR1726807, ERR1726816...
# NAO-all     ERR1726589, ERR1726676, ERR1726679, ERR1726693...
# IO-all      ERR1700889, ERR1700906, ERR1700907, ERR1700909...
# SAO-all     ERR1726572, ERR1726699, ERR1726733, ERR1726975...
# SPO-SPSG    ERR1726528, ERR1726544, ERR1726558, ERR1726588...
# SPO-SPSG    ERR1726541, ERR1726543, ERR1726561, ERR1726586...
# SPO-SPSG    ERR1726556, ERR1726564, ERR1726567, ERR1726569...
# SAO-all     ERR1726682, ERR1726701, ERR1726704, ERR1726793...
#
#                       Assembly_group
# Sub_region
# SPO-CHIL       SPO-CHIL-MES-0.8-5.00
# SPO-PEOD       SPO-PEOD-MES-0.8-5.00
# SPO-CHIL      SPO-CHIL-DCM-20-180.00
# RS-all            RS-all-DCM-5-20.00
# SO-all          SO-all-DCM-20-180.00
# SPO-CHIL        SPO-CHIL-DCM-5-20.00
# NAO-all          NAO-all-MIX-5-20.00
# SPO-PEOD    SPO-PEOD-DCM-180-2000.00
# NAO-all      NAO-all-MIX-180-2000.00
# SPO-PEOD        SPO-PEOD-DCM-5-20.00
# SO-all           SO-all-MES-0.8-5.00
# SPO-CHIL    SPO-CHIL-DCM-180-2000.00
# SPO-PEOD      SPO-PEOD-SRF-20-180.00
# SPO-PEOD        SPO-PEOD-SRF-5-20.00
# SO-all            SO-all-DCM-5-20.00
# SPO-PEOD      SPO-PEOD-DCM-20-180.00
# SPO-PEOD    SPO-PEOD-SRF-180-2000.00
# SO-all        SO-all-DCM-180-2000.00
# SPO-CHIL       SPO-CHIL-DCM-0.8-5.00
# RS-all           RS-all-DCM-0.8-5.00
# IO-all           IO-all-FSW-0.8-5.00
# RS-all          RS-all-DCM-20-180.00
# SO-all           SO-all-DCM-0.8-5.00
# RS-all        RS-all-DCM-180-2000.00
# NAO-all        NAO-all-MIX-20-180.00
# SPO-CHIL        SPO-CHIL-SRF-5-20.00
# SPO-CHIL      SPO-CHIL-SRF-20-180.00
# NAO-all        NAO-all-DCM-20-180.00
# SPO-PEOD       SPO-PEOD-SRF-0.8-5.00
# SO-all            SO-all-SRF-5-20.00
# ...                              ...
# NPO-all        NPO-all-DCM-20-180.00
# NAO-all        NAO-all-SRF-20-180.00
# NAO-all          NAO-all-SRF-5-20.00
# IO-all        IO-all-DCM-180-2000.00
# SPO-SPSG    SPO-SPSG-DCM-180-2000.00
# NPO-all      NPO-all-SRF-180-2000.00
# SAO-all          SAO-all-SRF-5-20.00
# IO-all            IO-all-SRF-5-20.00
# MS-all          MS-all-SRF-20-180.00
# IO-all           IO-all-DCM-0.8-5.00
# NAO-all      NAO-all-SRF-180-2000.00
# SAO-all      SAO-all-SRF-180-2000.00
# NPO-all          NPO-all-SRF-5-20.00
# NPO-all        NPO-all-SRF-20-180.00
# SAO-all        SAO-all-SRF-20-180.00
# MS-all           MS-all-SRF-0.8-5.00
# NPO-all         NPO-all-DCM-0.8-5.00
# MS-all        MS-all-SRF-180-2000.00
# IO-all          IO-all-SRF-20-180.00
# SPO-SPSG        SPO-SPSG-SRF-5-20.00
# SPO-SPSG       SPO-SPSG-DCM-0.8-5.00
# IO-all           IO-all-SRF-0.8-5.00
# NPO-all         NPO-all-SRF-0.8-5.00
# NAO-all         NAO-all-SRF-0.8-5.00
# IO-all        IO-all-SRF-180-2000.00
# SAO-all         SAO-all-SRF-0.8-5.00
# SPO-SPSG      SPO-SPSG-SRF-20-180.00
# SPO-SPSG    SPO-SPSG-SRF-180-2000.00
# SPO-SPSG       SPO-SPSG-SRF-0.8-5.00
# SAO-all         SAO-all-DCM-0.8-5.00
#
# [94 rows x 4 columns]

# %%
# Excess below?

# %%
sara = pd.read_csv('SampleList_ForAssembly.txt', sep = '\t', index_col = 'Sub_region')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-44-198846e5b37b> in <module>
# ----> 1 sara = pd.read_csv('SampleList_ForAssembly.txt', sep = '\t', index_col = 'Sub_region')
#
# ~/.conda/envs/r_3.5.1/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     700                     skip_blank_lines=skip_blank_lines)
#     701
# --> 702         return _read(filepath_or_buffer, kwds)
#     703
#     704     parser_f.__name__ = name
#
# ~/.conda/envs/r_3.5.1/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     427
#     428     # Create the parser.
# --> 429     parser = TextFileReader(filepath_or_buffer, **kwds)
#     430
#     431     if chunksize or iterator:
#
# ~/.conda/envs/r_3.5.1/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options['has_index_names'] = kwds['has_index_names']
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# ~/.conda/envs/r_3.5.1/lib/python3.6/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1120     def _make_engine(self, engine='c'):
#    1121         if engine == 'c':
# -> 1122             self._engine = CParserWrapper(self.f, **self.options)
#    1123         else:
#    1124             if engine == 'python':
#
# ~/.conda/envs/r_3.5.1/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1851         kwds['usecols'] = self.usecols
#    1852
# -> 1853         self._reader = parsers.TextReader(src, **kwds)
#    1854         self.unnamed_cols = self._reader.unnamed_cols
#    1855
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'SampleList_ForAssembly.txt' does not exist: b'SampleList_ForAssembly.txt'

# %%
set(metag_out.Depth_sizefrac.unique()).difference(set(sara.Depth_sizefrac.unique()))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-0faa28ce1673> in <module>
# ----> 1 set(metag_out.Depth_sizefrac.unique()).difference(set(sara.Depth_sizefrac.unique()))
#
# NameError: name 'sara' is not defined

# %%
set(metag.size_frac)
# Out:
# {'0.8-5.00', '180-2000.00', '20-180.00', '5-20.00'}

# %%
sara
# Out:
#              Depth_sizefrac  ERR_count  \
# Sub_region
# IO-all         DCM-0.8-5.00         13
# IO-all      DCM-180-2000.00         12
# IO-all        DCM-20-180.00         10
# IO-all          DCM-5-20.00          6
# IO-all         FSW-0.8-5.00          2
# IO-all         MES-0.8-5.00          8
# IO-all         SRF-0.8-5.00         20
# IO-all      SRF-180-2000.00         21
# IO-all        SRF-20-180.00         17
# IO-all          SRF-5-20.00         12
# IO-all         ZZZ-0.8-5.00          6
# MS-all         DCM-0.8-5.00         10
# MS-all      DCM-180-2000.00          8
# MS-all        DCM-20-180.00          7
# MS-all          DCM-5-20.00          7
# MS-all         SRF-0.8-5.00         14
# MS-all      SRF-180-2000.00         15
# MS-all        SRF-20-180.00         13
# MS-all          SRF-5-20.00          9
# NAO-all        DCM-0.8-5.00          8
# NAO-all     DCM-180-2000.00          4
# NAO-all       DCM-20-180.00          4
# NAO-all         DCM-5-20.00          5
# NAO-all        MES-0.8-5.00          9
# NAO-all        MIX-0.8-5.00          9
# NAO-all     MIX-180-2000.00          2
# NAO-all       MIX-20-180.00          3
# NAO-all         MIX-5-20.00          2
# NAO-all        SRF-0.8-5.00         20
# NAO-all     SRF-180-2000.00         13
# ...                     ...        ...
# SO-all        SRF-20-180.00          5
# SO-all          SRF-5-20.00          4
# SPO-CHIL       DCM-0.8-5.00          2
# SPO-CHIL    DCM-180-2000.00          2
# SPO-CHIL      DCM-20-180.00          1
# SPO-CHIL        DCM-5-20.00          2
# SPO-CHIL       MES-0.8-5.00          1
# SPO-CHIL       SRF-0.8-5.00          6
# SPO-CHIL    SRF-180-2000.00          4
# SPO-CHIL      SRF-20-180.00          4
# SPO-CHIL        SRF-5-20.00          3
# SPO-PEOD       DCM-0.8-5.00          5
# SPO-PEOD    DCM-180-2000.00          2
# SPO-PEOD      DCM-20-180.00          2
# SPO-PEOD        DCM-5-20.00          2
# SPO-PEOD       MES-0.8-5.00          1
# SPO-PEOD       SRF-0.8-5.00          4
# SPO-PEOD    SRF-180-2000.00          2
# SPO-PEOD      SRF-20-180.00          2
# SPO-PEOD        SRF-5-20.00          2
# SPO-SPSG       DCM-0.8-5.00         19
# SPO-SPSG    DCM-180-2000.00         12
# SPO-SPSG      DCM-20-180.00          7
# SPO-SPSG        DCM-5-20.00          9
# SPO-SPSG       MES-0.8-5.00          7
# SPO-SPSG       MIX-0.8-5.00          7
# SPO-SPSG       SRF-0.8-5.00         33
# SPO-SPSG    SRF-180-2000.00         27
# SPO-SPSG      SRF-20-180.00         25
# SPO-SPSG        SRF-5-20.00         18
#
#                                                      ERR_list  \
# Sub_region
# IO-all      ERR1726633, ERR1726897, ERR599323, ERR599324, ...
# IO-all      ERR1726526, ERR1726686, ERR1726696, ERR1726746...
# IO-all      ERR1726554, ERR1726590, ERR1726671, ERR1726736...
# IO-all      ERR1700904, ERR1700912, ERR1726665, ERR599205,...
# IO-all                                   ERR868368, ERR868484
# IO-all      ERR599212, ERR599225, ERR599268, ERR868353, ER...
# IO-all      ERR1726549, ERR1740328, ERR599210, ERR599266, ...
# IO-all      ERR1700889, ERR1700906, ERR1700907, ERR1700909...
# IO-all      ERR1700914, ERR1726587, ERR1726599, ERR1726611...
# IO-all      ERR1700890, ERR1700899, ERR1726575, ERR1726677...
# IO-all      ERR1700892, ERR1726582, ERR1726591, ERR1726862...
# MS-all      ERR538175, ERR538179, ERR538182, ERR868373, ER...
# MS-all      ERR1726557, ERR1726618, ERR1726672, ERR1726718...
# MS-all      ERR1726743, ERR1726811, ERR1726836, ERR1726855...
# MS-all      ERR1700894, ERR1700913, ERR1726585, ERR1726715...
# MS-all      ERR1726597, ERR538173, ERR538186, ERR868356, E...
# MS-all      ERR1726574, ERR1726612, ERR1726662, ERR1726681...
# MS-all      ERR1726546, ERR1726613, ERR1726642, ERR1726660...
# MS-all      ERR1700895, ERR1700896, ERR1726540, ERR1726555...
# NAO-all     ERR1726596, ERR868367, ERR868423, ERR868435, E...
# NAO-all        ERR1726617, ERR1726783, ERR1726824, ERR1726957
# NAO-all        ERR1726529, ERR1726852, ERR1726893, ERR1726911
# NAO-all     ERR1700891, ERR1700900, ERR1700908, ERR1726551...
# NAO-all     ERR868349, ERR868380, ERR868434, ERR868449, ER...
# NAO-all     ERR1726629, ERR1726707, ERR1726761, ERR1726821...
# NAO-all                                ERR1726532, ERR1726941
# NAO-all                    ERR1726653, ERR1726803, ERR1726947
# NAO-all                                ERR1726545, ERR1726756
# NAO-all     ERR1726589, ERR1726676, ERR1726679, ERR1726693...
# NAO-all     ERR1726553, ERR1726638, ERR1726654, ERR1726712...
# ...                                                       ...
# SO-all      ERR1726781, ERR1726799, ERR1726901, ERR599264,...
# SO-all           ERR1726939, ERR1726968, ERR599224, ERR599228
# SPO-CHIL                                 ERR868358, ERR868505
# SPO-CHIL                               ERR1726566, ERR1726627
# SPO-CHIL                                           ERR1726830
# SPO-CHIL                               ERR1700901, ERR1726828
# SPO-CHIL                                            ERR868377
# SPO-CHIL    ERR1726645, ERR1726719, ERR1726749, ERR868413,...
# SPO-CHIL       ERR1726740, ERR1726790, ERR1726876, ERR1726895
# SPO-CHIL       ERR1726524, ERR1726525, ERR1726850, ERR1726952
# SPO-CHIL                   ERR1726632, ERR1726713, ERR1726878
# SPO-PEOD    ERR1726842, ERR1726858, ERR868422, ERR868440, ...
# SPO-PEOD                               ERR1700911, ERR1726962
# SPO-PEOD                               ERR1726659, ERR1726727
# SPO-PEOD                               ERR1726562, ERR1726742
# SPO-PEOD                                            ERR868362
# SPO-PEOD         ERR1726628, ERR1726851, ERR868357, ERR868462
# SPO-PEOD                               ERR1726705, ERR1726795
# SPO-PEOD                               ERR1726577, ERR1726709
# SPO-PEOD                               ERR1726594, ERR1726841
# SPO-SPSG    ERR1726527, ERR1726579, ERR1726584, ERR1726609...
# SPO-SPSG    ERR1726550, ERR1726552, ERR1726604, ERR1726623...
# SPO-SPSG    ERR1726603, ERR1726606, ERR1726655, ERR1726690...
# SPO-SPSG    ERR1700897, ERR1700903, ERR1700905, ERR1726668...
# SPO-SPSG    ERR868365, ERR868379, ERR868417, ERR868443, ER...
# SPO-SPSG    ERR868359, ERR868360, ERR868371, ERR868426, ER...
# SPO-SPSG    ERR1726556, ERR1726564, ERR1726567, ERR1726569...
# SPO-SPSG    ERR1726541, ERR1726543, ERR1726561, ERR1726586...
# SPO-SPSG    ERR1726528, ERR1726544, ERR1726558, ERR1726588...
# SPO-SPSG    ERR1726522, ERR1726533, ERR1726535, ERR1726571...
#
#                       Assembly_group
# Sub_region
# IO-all           IO-all-DCM-0.8-5.00
# IO-all        IO-all-DCM-180-2000.00
# IO-all          IO-all-DCM-20-180.00
# IO-all            IO-all-DCM-5-20.00
# IO-all           IO-all-FSW-0.8-5.00
# IO-all           IO-all-MES-0.8-5.00
# IO-all           IO-all-SRF-0.8-5.00
# IO-all        IO-all-SRF-180-2000.00
# IO-all          IO-all-SRF-20-180.00
# IO-all            IO-all-SRF-5-20.00
# IO-all           IO-all-ZZZ-0.8-5.00
# MS-all           MS-all-DCM-0.8-5.00
# MS-all        MS-all-DCM-180-2000.00
# MS-all          MS-all-DCM-20-180.00
# MS-all            MS-all-DCM-5-20.00
# MS-all           MS-all-SRF-0.8-5.00
# MS-all        MS-all-SRF-180-2000.00
# MS-all          MS-all-SRF-20-180.00
# MS-all            MS-all-SRF-5-20.00
# NAO-all         NAO-all-DCM-0.8-5.00
# NAO-all      NAO-all-DCM-180-2000.00
# NAO-all        NAO-all-DCM-20-180.00
# NAO-all          NAO-all-DCM-5-20.00
# NAO-all         NAO-all-MES-0.8-5.00
# NAO-all         NAO-all-MIX-0.8-5.00
# NAO-all      NAO-all-MIX-180-2000.00
# NAO-all        NAO-all-MIX-20-180.00
# NAO-all          NAO-all-MIX-5-20.00
# NAO-all         NAO-all-SRF-0.8-5.00
# NAO-all      NAO-all-SRF-180-2000.00
# ...                              ...
# SO-all          SO-all-SRF-20-180.00
# SO-all            SO-all-SRF-5-20.00
# SPO-CHIL       SPO-CHIL-DCM-0.8-5.00
# SPO-CHIL    SPO-CHIL-DCM-180-2000.00
# SPO-CHIL      SPO-CHIL-DCM-20-180.00
# SPO-CHIL        SPO-CHIL-DCM-5-20.00
# SPO-CHIL       SPO-CHIL-MES-0.8-5.00
# SPO-CHIL       SPO-CHIL-SRF-0.8-5.00
# SPO-CHIL    SPO-CHIL-SRF-180-2000.00
# SPO-CHIL      SPO-CHIL-SRF-20-180.00
# SPO-CHIL        SPO-CHIL-SRF-5-20.00
# SPO-PEOD       SPO-PEOD-DCM-0.8-5.00
# SPO-PEOD    SPO-PEOD-DCM-180-2000.00
# SPO-PEOD      SPO-PEOD-DCM-20-180.00
# SPO-PEOD        SPO-PEOD-DCM-5-20.00
# SPO-PEOD       SPO-PEOD-MES-0.8-5.00
# SPO-PEOD       SPO-PEOD-SRF-0.8-5.00
# SPO-PEOD    SPO-PEOD-SRF-180-2000.00
# SPO-PEOD      SPO-PEOD-SRF-20-180.00
# SPO-PEOD        SPO-PEOD-SRF-5-20.00
# SPO-SPSG       SPO-SPSG-DCM-0.8-5.00
# SPO-SPSG    SPO-SPSG-DCM-180-2000.00
# SPO-SPSG      SPO-SPSG-DCM-20-180.00
# SPO-SPSG        SPO-SPSG-DCM-5-20.00
# SPO-SPSG       SPO-SPSG-MES-0.8-5.00
# SPO-SPSG       SPO-SPSG-MIX-0.8-5.00
# SPO-SPSG       SPO-SPSG-SRF-0.8-5.00
# SPO-SPSG    SPO-SPSG-SRF-180-2000.00
# SPO-SPSG      SPO-SPSG-SRF-20-180.00
# SPO-SPSG        SPO-SPSG-SRF-5-20.00
#
# [94 rows x 4 columns]

# %%
# Out:
# 94
